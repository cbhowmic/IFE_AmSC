# %%
from pathlib import Path
import sys
import numpy as np
import pandas as pd
import openpmd_api as io
from rhinoWrite_particle_red import save_bp

# %%
ROOT_PATH=Path("/global/cfs/cdirs/m3239/2026_FES-AmSC/data/rhino/Surrogate Data/")
# SCENARIOS=[f"Power&BurnFractionScan_Daily_Reduced{i}" for i in (1,2)]
SCENARIOS=["2026-04-29", "2026-04-30", "2026-05-01"]

# %%
OUTPUT_ROOT=Path("/global/cfs/cdirs/m3239/2026_FES-AmSC/data/rhino/surrogate_bp_output/")
# OUTPUT_ROOT=Path("/global/cfs/cdirs/m3239/aforment/IFE_AmSC/RHINO/scripts/tmp")

# %%
for scenario in SCENARIOS:
    print(scenario)
    try:
        scenario_path = ROOT_PATH / scenario
        data_root = scenario_path

        if not data_root.exists():
            print(f"Scenario folder missing or no Data/: {data_root} — skipping")
            continue
        
        for tfile in sorted(data_root.glob("*_T_reduced.pkl")):
            try:
                # Extract correct prefixes
                run_prefix_data = tfile.name.split("_T_reduced.pkl")[0]
                run_prefix_meta = "_".join(run_prefix_data.split("_")[:2])
                run_time_prefix = run_prefix_data.split("_")[0]
                
                prefix = run_time_prefix 
                infix = "_".join(run_prefix_data.split("_")[1:])
                #print(f"Found run: {infix}")
                if scenario==SCENARIOS[1] and prefix=="03-51-04":
                    continue
                    
            except Exception as e:
                print(f"ERROR processing run '{run_prefix_data}' in scenario '{scenario}': {e}")
                continue

            # build output path 
            safe_param = scenario.replace(" ", "_")
            safe_param = safe_param.replace("&", "And")
            
            out_name = f"{safe_param}/{run_time_prefix}.bp5"
            OUTPUT_PATH = OUTPUT_ROOT / out_name
        
            save_bp(scenario_path, prefix, infix, OUTPUT_PATH)
    
    except Exception as e:
        print(f"ERROR processing scenario '{scenario}': {e}")
        continue
# Out:
# 2026-04-29
# Converting RHINO data into openPMD/ADIOS2 format...
# Input: /global/cfs/cdirs/m3239/2026_FES-AmSC/data/rhino/Surrogate Data/2026-04-29
# RHINO data written to ADIOS-OpenPMD in particle representation.
# Output: /global/cfs/cdirs/m3239/2026_FES-AmSC/data/rhino/surrogate_bp_output/2026-04-29/14-21-14.bp5
# Converting RHINO data into openPMD/ADIOS2 format...
# Input: /global/cfs/cdirs/m3239/2026_FES-AmSC/data/rhino/Surrogate Data/2026-04-29
# RHINO data written to ADIOS-OpenPMD in particle representation.
# Output: /global/cfs/cdirs/m3239/2026_FES-AmSC/data/rhino/surrogate_bp_output/2026-04-29/14-22-30.bp5
# Converting RHINO data into openPMD/ADIOS2 format...
# Input: /global/cfs/cdirs/m3239/2026_FES-AmSC/data/rhino/Surrogate Data/2026-04-29
# RHINO data written to ADIOS-OpenPMD in particle representation.
# Output: /global/cfs/cdirs/m3239/2026_FES-AmSC/data/rhino/surrogate_bp_output/2026-04-29/14-23-03.bp5
# Converting RHINO data into openPMD/ADIOS2 format...
# Input: /global/cfs/cdirs/m3239/2026_FES-AmSC/data/rhino/Surrogate Data/2026-04-29
# RHINO data written to ADIOS-OpenPMD in particle representation.
# Output: /global/cfs/cdirs/m3239/2026_FES-AmSC/data/rhino/surrogate_bp_output/2026-04-29/14-23-33.bp5
# Converting RHINO data into openPMD/ADIOS2 format...
# Input: /global/cfs/cdirs/m3239/2026_FES-AmSC/data/rhino/Surrogate Data/2026-04-29
# RHINO data written to ADIOS-OpenPMD in particle representation.
# Output: /global/cfs/cdirs/m3239/2026_FES-AmSC/data/rhino/surrogate_bp_output/2026-04-29/14-24-04.bp5
# Converting RHINO data into openPMD/ADIOS2 format...
# Input: /global/cfs/cdirs/m3239/2026_FES-AmSC/data/rhino/Surrogate Data/2026-04-29
# RHINO data written to ADIOS-OpenPMD in particle representation.
# Output: /global/cfs/cdirs/m3239/2026_FES-AmSC/data/rhino/surrogate_bp_output/2026-04-29/14-24-37.bp5
# Converting RHINO data into openPMD/ADIOS2 format...
# Input: /global/cfs/cdirs/m3239/2026_FES-AmSC/data/rhino/Surrogate Data/2026-04-29
# RHINO data written to ADIOS-OpenPMD in particle representation.
# Output: /global/cfs/cdirs/m3239/2026_FES-AmSC/data/rhino/surrogate_bp_output/2026-04-29/14-25-07.bp5
# Converting RHINO data into openPMD/ADIOS2 format...
# Input: /global/cfs/cdirs/m3239/2026_FES-AmSC/data/rhino/Surrogate Data/2026-04-29
# RHINO data written to ADIOS-OpenPMD in particle representation.
# Output: /global/cfs/cdirs/m3239/2026_FES-AmSC/data/rhino/surrogate_bp_output/2026-04-29/14-25-38.bp5
# Converting RHINO data into openPMD/ADIOS2 format...
# Input: /global/cfs/cdirs/m3239/2026_FES-AmSC/data/rhino/Surrogate Data/2026-04-29
# RHINO data written to ADIOS-OpenPMD in particle representation.
# Output: /global/cfs/cdirs/m3239/2026_FES-AmSC/data/rhino/surrogate_bp_output/2026-04-29/14-26-10.bp5
# Converting RHINO data into openPMD/ADIOS2 format...
# Input: /global/cfs/cdirs/m3239/2026_FES-AmSC/data/rhino/Surrogate Data/2026-04-29
# RHINO data written to ADIOS-OpenPMD in particle representation.
# Output: /global/cfs/cdirs/m3239/2026_FES-AmSC/data/rhino/surrogate_bp_output/2026-04-29/14-26-40.bp5
# Converting RHINO data into openPMD/ADIOS2 format...
# Input: /global/cfs/cdirs/m3239/2026_FES-AmSC/data/rhino/Surrogate Data/2026-04-29
# RHINO data written to ADIOS-OpenPMD in particle representation.
# Output: /global/cfs/cdirs/m3239/2026_FES-AmSC/data/rhino/surrogate_bp_output/2026-04-29/14-27-11.bp5
# Converting RHINO data into openPMD/ADIOS2 format...
# Input: /global/cfs/cdirs/m3239/2026_FES-AmSC/data/rhino/Surrogate Data/2026-04-29
# RHINO data written to ADIOS-OpenPMD in particle representation.
# Output: /global/cfs/cdirs/m3239/2026_FES-AmSC/data/rhino/surrogate_bp_output/2026-04-29/14-27-44.bp5
# Converting RHINO data into openPMD/ADIOS2 format...
# Input: /global/cfs/cdirs/m3239/2026_FES-AmSC/data/rhino/Surrogate Data/2026-04-29
# RHINO data written to ADIOS-OpenPMD in particle representation.
# Output: /global/cfs/cdirs/m3239/2026_FES-AmSC/data/rhino/surrogate_bp_output/2026-04-29/14-28-15.bp5
# Converting RHINO data into openPMD/ADIOS2 format...
# Input: /global/cfs/cdirs/m3239/2026_FES-AmSC/data/rhino/Surrogate Data/2026-04-29
# RHINO data written to ADIOS-OpenPMD in particle representation.
# Output: /global/cfs/cdirs/m3239/2026_FES-AmSC/data/rhino/surrogate_bp_output/2026-04-29/14-28-47.bp5
# Converting RHINO data into openPMD/ADIOS2 format...
# Input: /global/cfs/cdirs/m3239/2026_FES-AmSC/data/rhino/Surrogate Data/2026-04-29
# RHINO data written to ADIOS-OpenPMD in particle representation.
# Output: /global/cfs/cdirs/m3239/2026_FES-AmSC/data/rhino/surrogate_bp_output/2026-04-29/14-29-17.bp5
# Converting RHINO data into openPMD/ADIOS2 format...
# Input: /global/cfs/cdirs/m3239/2026_FES-AmSC/data/rhino/Surrogate Data/2026-04-29
# RHINO data written to ADIOS-OpenPMD in particle representation.
# Output: /global/cfs/cdirs/m3239/2026_FES-AmSC/data/rhino/surrogate_bp_output/2026-04-29/14-29-47.bp5
# Converting RHINO data into openPMD/ADIOS2 format...
# Input: /global/cfs/cdirs/m3239/2026_FES-AmSC/data/rhino/Surrogate Data/2026-04-29
# RHINO data written to ADIOS-OpenPMD in particle representation.
# Output: /global/cfs/cdirs/m3239/2026_FES-AmSC/data/rhino/surrogate_bp_output/2026-04-29/14-30-21.bp5
# Converting RHINO data into openPMD/ADIOS2 format...
# Input: /global/cfs/cdirs/m3239/2026_FES-AmSC/data/rhino/Surrogate Data/2026-04-29
# RHINO data written to ADIOS-OpenPMD in particle representation.
# Output: /global/cfs/cdirs/m3239/2026_FES-AmSC/data/rhino/surrogate_bp_output/2026-04-29/14-30-53.bp5
# Converting RHINO data into openPMD/ADIOS2 format...
# Input: /global/cfs/cdirs/m3239/2026_FES-AmSC/data/rhino/Surrogate Data/2026-04-29
# RHINO data written to ADIOS-OpenPMD in particle representation.
# Output: /global/cfs/cdirs/m3239/2026_FES-AmSC/data/rhino/surrogate_bp_output/2026-04-29/14-31-25.bp5
# Converting RHINO data into openPMD/ADIOS2 format...
# Input: /global/cfs/cdirs/m3239/2026_FES-AmSC/data/rhino/Surrogate Data/2026-04-29
# RHINO data written to ADIOS-OpenPMD in particle representation.
# Output: /global/cfs/cdirs/m3239/2026_FES-AmSC/data/rhino/surrogate_bp_output/2026-04-29/14-31-57.bp5
# Converting RHINO data into openPMD/ADIOS2 format...
# Input: /global/cfs/cdirs/m3239/2026_FES-AmSC/data/rhino/Surrogate Data/2026-04-29
# RHINO data written to ADIOS-OpenPMD in particle representation.
# Output: /global/cfs/cdirs/m3239/2026_FES-AmSC/data/rhino/surrogate_bp_output/2026-04-29/14-32-28.bp5
# Converting RHINO data into openPMD/ADIOS2 format...
# Input: /global/cfs/cdirs/m3239/2026_FES-AmSC/data/rhino/Surrogate Data/2026-04-29
# RHINO data written to ADIOS-OpenPMD in particle representation.
# Output: /global/cfs/cdirs/m3239/2026_FES-AmSC/data/rhino/surrogate_bp_output/2026-04-29/14-33-01.bp5
# Converting RHINO data into openPMD/ADIOS2 format...
# Input: /global/cfs/cdirs/m3239/2026_FES-AmSC/data/rhino/Surrogate Data/2026-04-29
# RHINO data written to ADIOS-OpenPMD in particle representation.
# Output: /global/cfs/cdirs/m3239/2026_FES-AmSC/data/rhino/surrogate_bp_output/2026-04-29/14-33-31.bp5
# Converting RHINO data into openPMD/ADIOS2 format...
# Input: /global/cfs/cdirs/m3239/2026_FES-AmSC/data/rhino/Surrogate Data/2026-04-29
# RHINO data written to ADIOS-OpenPMD in particle representation.
# Output: /global/cfs/cdirs/m3239/2026_FES-AmSC/data/rhino/surrogate_bp_output/2026-04-29/14-34-01.bp5
# Converting RHINO data into openPMD/ADIOS2 format...
# Input: /global/cfs/cdirs/m3239/2026_FES-AmSC/data/rhino/Surrogate Data/2026-04-29
# RHINO data written to ADIOS-OpenPMD in particle representation.
# Output: /global/cfs/cdirs/m3239/2026_FES-AmSC/data/rhino/surrogate_bp_output/2026-04-29/14-34-31.bp5
# Converting RHINO data into openPMD/ADIOS2 format...
# Input: /global/cfs/cdirs/m3239/2026_FES-AmSC/data/rhino/Surrogate Data/2026-04-29
# RHINO data written to ADIOS-OpenPMD in particle representation.
# Output: /global/cfs/cdirs/m3239/2026_FES-AmSC/data/rhino/surrogate_bp_output/2026-04-29/14-35-03.bp5
# Converting RHINO data into openPMD/ADIOS2 format...
# Input: /global/cfs/cdirs/m3239/2026_FES-AmSC/data/rhino/Surrogate Data/2026-04-29
# RHINO data written to ADIOS-OpenPMD in particle representation.
# Output: /global/cfs/cdirs/m3239/2026_FES-AmSC/data/rhino/surrogate_bp_output/2026-04-29/14-35-33.bp5
# Converting RHINO data into openPMD/ADIOS2 format...
# Input: /global/cfs/cdirs/m3239/2026_FES-AmSC/data/rhino/Surrogate Data/2026-04-29
# RHINO data written to ADIOS-OpenPMD in particle representation.
# Output: /global/cfs/cdirs/m3239/2026_FES-AmSC/data/rhino/surrogate_bp_output/2026-04-29/14-36-02.bp5
# Converting RHINO data into openPMD/ADIOS2 format...
# Input: /global/cfs/cdirs/m3239/2026_FES-AmSC/data/rhino/Surrogate Data/2026-04-29
# RHINO data written to ADIOS-OpenPMD in particle representation.
# Output: /global/cfs/cdirs/m3239/2026_FES-AmSC/data/rhino/surrogate_bp_output/2026-04-29/14-36-34.bp5
# Converting RHINO data into openPMD/ADIOS2 format...
# Input: /global/cfs/cdirs/m3239/2026_FES-AmSC/data/rhino/Surrogate Data/2026-04-29
# RHINO data written to ADIOS-OpenPMD in particle representation.
# Output: /global/cfs/cdirs/m3239/2026_FES-AmSC/data/rhino/surrogate_bp_output/2026-04-29/14-37-05.bp5
# Converting RHINO data into openPMD/ADIOS2 format...
# Input: /global/cfs/cdirs/m3239/2026_FES-AmSC/data/rhino/Surrogate Data/2026-04-29
# RHINO data written to ADIOS-OpenPMD in particle representation.
# Output: /global/cfs/cdirs/m3239/2026_FES-AmSC/data/rhino/surrogate_bp_output/2026-04-29/14-37-35.bp5
# Converting RHINO data into openPMD/ADIOS2 format...
# Input: /global/cfs/cdirs/m3239/2026_FES-AmSC/data/rhino/Surrogate Data/2026-04-29
# RHINO data written to ADIOS-OpenPMD in particle representation.
# Output: /global/cfs/cdirs/m3239/2026_FES-AmSC/data/rhino/surrogate_bp_output/2026-04-29/14-38-06.bp5
# Converting RHINO data into openPMD/ADIOS2 format...
# Input: /global/cfs/cdirs/m3239/2026_FES-AmSC/data/rhino/Surrogate Data/2026-04-29
# RHINO data written to ADIOS-OpenPMD in particle representation.
# Output: /global/cfs/cdirs/m3239/2026_FES-AmSC/data/rhino/surrogate_bp_output/2026-04-29/14-38-38.bp5
# Converting RHINO data into openPMD/ADIOS2 format...
# Input: /global/cfs/cdirs/m3239/2026_FES-AmSC/data/rhino/Surrogate Data/2026-04-29
# RHINO data written to ADIOS-OpenPMD in particle representation.
# Output: /global/cfs/cdirs/m3239/2026_FES-AmSC/data/rhino/surrogate_bp_output/2026-04-29/14-39-08.bp5
# Converting RHINO data into openPMD/ADIOS2 format...
# Input: /global/cfs/cdirs/m3239/2026_FES-AmSC/data/rhino/Surrogate Data/2026-04-29
# RHINO data written to ADIOS-OpenPMD in particle representation.
# Output: /global/cfs/cdirs/m3239/2026_FES-AmSC/data/rhino/surrogate_bp_output/2026-04-29/14-39-40.bp5
# Converting RHINO data into openPMD/ADIOS2 format...
# Input: /global/cfs/cdirs/m3239/2026_FES-AmSC/data/rhino/Surrogate Data/2026-04-29
# RHINO data written to ADIOS-OpenPMD in particle representation.
# Output: /global/cfs/cdirs/m3239/2026_FES-AmSC/data/rhino/surrogate_bp_output/2026-04-29/14-40-11.bp5
# Converting RHINO data into openPMD/ADIOS2 format...
# Input: /global/cfs/cdirs/m3239/2026_FES-AmSC/data/rhino/Surrogate Data/2026-04-29
# RHINO data written to ADIOS-OpenPMD in particle representation.
# Output: /global/cfs/cdirs/m3239/2026_FES-AmSC/data/rhino/surrogate_bp_output/2026-04-29/14-40-41.bp5
# Converting RHINO data into openPMD/ADIOS2 format...
# Input: /global/cfs/cdirs/m3239/2026_FES-AmSC/data/rhino/Surrogate Data/2026-04-29
# RHINO data written to ADIOS-OpenPMD in particle representation.
# Output: /global/cfs/cdirs/m3239/2026_FES-AmSC/data/rhino/surrogate_bp_output/2026-04-29/14-41-12.bp5
# Converting RHINO data into openPMD/ADIOS2 format...
# Input: /global/cfs/cdirs/m3239/2026_FES-AmSC/data/rhino/Surrogate Data/2026-04-29
# RHINO data written to ADIOS-OpenPMD in particle representation.
# Output: /global/cfs/cdirs/m3239/2026_FES-AmSC/data/rhino/surrogate_bp_output/2026-04-29/14-41-44.bp5
# Converting RHINO data into openPMD/ADIOS2 format...
# Input: /global/cfs/cdirs/m3239/2026_FES-AmSC/data/rhino/Surrogate Data/2026-04-29
# RHINO data written to ADIOS-OpenPMD in particle representation.
# Output: /global/cfs/cdirs/m3239/2026_FES-AmSC/data/rhino/surrogate_bp_output/2026-04-29/14-42-14.bp5
# Converting RHINO data into openPMD/ADIOS2 format...
# Input: /global/cfs/cdirs/m3239/2026_FES-AmSC/data/rhino/Surrogate Data/2026-04-29
# RHINO data written to ADIOS-OpenPMD in particle representation.
# Output: /global/cfs/cdirs/m3239/2026_FES-AmSC/data/rhino/surrogate_bp_output/2026-04-29/14-42-45.bp5
# Converting RHINO data into openPMD/ADIOS2 format...
# Input: /global/cfs/cdirs/m3239/2026_FES-AmSC/data/rhino/Surrogate Data/2026-04-29
# RHINO data written to ADIOS-OpenPMD in particle representation.
# Output: /global/cfs/cdirs/m3239/2026_FES-AmSC/data/rhino/surrogate_bp_output/2026-04-29/14-43-15.bp5
# Converting RHINO data into openPMD/ADIOS2 format...
# Input: /global/cfs/cdirs/m3239/2026_FES-AmSC/data/rhino/Surrogate Data/2026-04-29
# RHINO data written to ADIOS-OpenPMD in particle representation.
# Output: /global/cfs/cdirs/m3239/2026_FES-AmSC/data/rhino/surrogate_bp_output/2026-04-29/14-43-45.bp5
# Converting RHINO data into openPMD/ADIOS2 format...
# Input: /global/cfs/cdirs/m3239/2026_FES-AmSC/data/rhino/Surrogate Data/2026-04-29
# RHINO data written to ADIOS-OpenPMD in particle representation.
# Output: /global/cfs/cdirs/m3239/2026_FES-AmSC/data/rhino/surrogate_bp_output/2026-04-29/14-44-18.bp5
# Converting RHINO data into openPMD/ADIOS2 format...
# Input: /global/cfs/cdirs/m3239/2026_FES-AmSC/data/rhino/Surrogate Data/2026-04-29
# RHINO data written to ADIOS-OpenPMD in particle representation.
# Output: /global/cfs/cdirs/m3239/2026_FES-AmSC/data/rhino/surrogate_bp_output/2026-04-29/14-44-52.bp5
# Converting RHINO data into openPMD/ADIOS2 format...
# Input: /global/cfs/cdirs/m3239/2026_FES-AmSC/data/rhino/Surrogate Data/2026-04-29
# RHINO data written to ADIOS-OpenPMD in particle representation.
# Output: /global/cfs/cdirs/m3239/2026_FES-AmSC/data/rhino/surrogate_bp_output/2026-04-29/14-45-22.bp5
# Converting RHINO data into openPMD/ADIOS2 format...
# Input: /global/cfs/cdirs/m3239/2026_FES-AmSC/data/rhino/Surrogate Data/2026-04-29
# RHINO data written to ADIOS-OpenPMD in particle representation.
# Output: /global/cfs/cdirs/m3239/2026_FES-AmSC/data/rhino/surrogate_bp_output/2026-04-29/14-45-52.bp5
# Converting RHINO data into openPMD/ADIOS2 format...
# Input: /global/cfs/cdirs/m3239/2026_FES-AmSC/data/rhino/Surrogate Data/2026-04-29
# RHINO data written to ADIOS-OpenPMD in particle representation.
# Output: /global/cfs/cdirs/m3239/2026_FES-AmSC/data/rhino/surrogate_bp_output/2026-04-29/14-46-24.bp5
# Converting RHINO data into openPMD/ADIOS2 format...
# Input: /global/cfs/cdirs/m3239/2026_FES-AmSC/data/rhino/Surrogate Data/2026-04-29
# RHINO data written to ADIOS-OpenPMD in particle representation.
# Output: /global/cfs/cdirs/m3239/2026_FES-AmSC/data/rhino/surrogate_bp_output/2026-04-29/14-46-54.bp5
# Converting RHINO data into openPMD/ADIOS2 format...
# Input: /global/cfs/cdirs/m3239/2026_FES-AmSC/data/rhino/Surrogate Data/2026-04-29
# RHINO data written to ADIOS-OpenPMD in particle representation.
# Output: /global/cfs/cdirs/m3239/2026_FES-AmSC/data/rhino/surrogate_bp_output/2026-04-29/14-47-26.bp5
# Converting RHINO data into openPMD/ADIOS2 format...
# Input: /global/cfs/cdirs/m3239/2026_FES-AmSC/data/rhino/Surrogate Data/2026-04-29
# RHINO data written to ADIOS-OpenPMD in particle representation.
# Output: /global/cfs/cdirs/m3239/2026_FES-AmSC/data/rhino/surrogate_bp_output/2026-04-29/14-47-57.bp5
# Converting RHINO data into openPMD/ADIOS2 format...
# Input: /global/cfs/cdirs/m3239/2026_FES-AmSC/data/rhino/Surrogate Data/2026-04-29
# RHINO data written to ADIOS-OpenPMD in particle representation.
# Output: /global/cfs/cdirs/m3239/2026_FES-AmSC/data/rhino/surrogate_bp_output/2026-04-29/14-48-30.bp5
# Converting RHINO data into openPMD/ADIOS2 format...
# Input: /global/cfs/cdirs/m3239/2026_FES-AmSC/data/rhino/Surrogate Data/2026-04-29
# RHINO data written to ADIOS-OpenPMD in particle representation.
# Output: /global/cfs/cdirs/m3239/2026_FES-AmSC/data/rhino/surrogate_bp_output/2026-04-29/14-49-03.bp5
# Converting RHINO data into openPMD/ADIOS2 format...
# Input: /global/cfs/cdirs/m3239/2026_FES-AmSC/data/rhino/Surrogate Data/2026-04-29
# RHINO data written to ADIOS-OpenPMD in particle representation.
# Output: /global/cfs/cdirs/m3239/2026_FES-AmSC/data/rhino/surrogate_bp_output/2026-04-29/14-49-34.bp5
# Converting RHINO data into openPMD/ADIOS2 format...
# Input: /global/cfs/cdirs/m3239/2026_FES-AmSC/data/rhino/Surrogate Data/2026-04-29
# RHINO data written to ADIOS-OpenPMD in particle representation.
# Output: /global/cfs/cdirs/m3239/2026_FES-AmSC/data/rhino/surrogate_bp_output/2026-04-29/14-50-06.bp5
# Converting RHINO data into openPMD/ADIOS2 format...
# Input: /global/cfs/cdirs/m3239/2026_FES-AmSC/data/rhino/Surrogate Data/2026-04-29
# RHINO data written to ADIOS-OpenPMD in particle representation.
# Output: /global/cfs/cdirs/m3239/2026_FES-AmSC/data/rhino/surrogate_bp_output/2026-04-29/14-50-37.bp5
# Converting RHINO data into openPMD/ADIOS2 format...
# Input: /global/cfs/cdirs/m3239/2026_FES-AmSC/data/rhino/Surrogate Data/2026-04-29
# RHINO data written to ADIOS-OpenPMD in particle representation.
# Output: /global/cfs/cdirs/m3239/2026_FES-AmSC/data/rhino/surrogate_bp_output/2026-04-29/14-51-08.bp5
# Converting RHINO data into openPMD/ADIOS2 format...
# Input: /global/cfs/cdirs/m3239/2026_FES-AmSC/data/rhino/Surrogate Data/2026-04-29
# RHINO data written to ADIOS-OpenPMD in particle representation.
# Output: /global/cfs/cdirs/m3239/2026_FES-AmSC/data/rhino/surrogate_bp_output/2026-04-29/14-51-39.bp5
# Converting RHINO data into openPMD/ADIOS2 format...
# Input: /global/cfs/cdirs/m3239/2026_FES-AmSC/data/rhino/Surrogate Data/2026-04-29
# RHINO data written to ADIOS-OpenPMD in particle representation.
# Output: /global/cfs/cdirs/m3239/2026_FES-AmSC/data/rhino/surrogate_bp_output/2026-04-29/14-52-09.bp5
# Converting RHINO data into openPMD/ADIOS2 format...
# Input: /global/cfs/cdirs/m3239/2026_FES-AmSC/data/rhino/Surrogate Data/2026-04-29
# RHINO data written to ADIOS-OpenPMD in particle representation.
# Output: /global/cfs/cdirs/m3239/2026_FES-AmSC/data/rhino/surrogate_bp_output/2026-04-29/14-52-40.bp5
# Converting RHINO data into openPMD/ADIOS2 format...
# Input: /global/cfs/cdirs/m3239/2026_FES-AmSC/data/rhino/Surrogate Data/2026-04-29
# RHINO data written to ADIOS-OpenPMD in particle representation.
# Output: /global/cfs/cdirs/m3239/2026_FES-AmSC/data/rhino/surrogate_bp_output/2026-04-29/14-53-12.bp5
# Converting RHINO data into openPMD/ADIOS2 format...
# Input: /global/cfs/cdirs/m3239/2026_FES-AmSC/data/rhino/Surrogate Data/2026-04-29
# RHINO data written to ADIOS-OpenPMD in particle representation.
# Output: /global/cfs/cdirs/m3239/2026_FES-AmSC/data/rhino/surrogate_bp_output/2026-04-29/14-53-43.bp5
# Converting RHINO data into openPMD/ADIOS2 format...
# Input: /global/cfs/cdirs/m3239/2026_FES-AmSC/data/rhino/Surrogate Data/2026-04-29
# RHINO data written to ADIOS-OpenPMD in particle representation.
# Output: /global/cfs/cdirs/m3239/2026_FES-AmSC/data/rhino/surrogate_bp_output/2026-04-29/14-54-15.bp5
# Converting RHINO data into openPMD/ADIOS2 format...
# Input: /global/cfs/cdirs/m3239/2026_FES-AmSC/data/rhino/Surrogate Data/2026-04-29
# RHINO data written to ADIOS-OpenPMD in particle representation.
# Output: /global/cfs/cdirs/m3239/2026_FES-AmSC/data/rhino/surrogate_bp_output/2026-04-29/14-54-46.bp5
# Converting RHINO data into openPMD/ADIOS2 format...
# Input: /global/cfs/cdirs/m3239/2026_FES-AmSC/data/rhino/Surrogate Data/2026-04-29
# RHINO data written to ADIOS-OpenPMD in particle representation.
# Output: /global/cfs/cdirs/m3239/2026_FES-AmSC/data/rhino/surrogate_bp_output/2026-04-29/14-55-18.bp5
# Converting RHINO data into openPMD/ADIOS2 format...
# Input: /global/cfs/cdirs/m3239/2026_FES-AmSC/data/rhino/Surrogate Data/2026-04-29
# RHINO data written to ADIOS-OpenPMD in particle representation.
# Output: /global/cfs/cdirs/m3239/2026_FES-AmSC/data/rhino/surrogate_bp_output/2026-04-29/14-55-49.bp5
# Converting RHINO data into openPMD/ADIOS2 format...
# Input: /global/cfs/cdirs/m3239/2026_FES-AmSC/data/rhino/Surrogate Data/2026-04-29
# RHINO data written to ADIOS-OpenPMD in particle representation.
# Output: /global/cfs/cdirs/m3239/2026_FES-AmSC/data/rhino/surrogate_bp_output/2026-04-29/14-56-20.bp5
# Converting RHINO data into openPMD/ADIOS2 format...
# Input: /global/cfs/cdirs/m3239/2026_FES-AmSC/data/rhino/Surrogate Data/2026-04-29
# RHINO data written to ADIOS-OpenPMD in particle representation.
# Output: /global/cfs/cdirs/m3239/2026_FES-AmSC/data/rhino/surrogate_bp_output/2026-04-29/14-56-51.bp5
# Converting RHINO data into openPMD/ADIOS2 format...
# Input: /global/cfs/cdirs/m3239/2026_FES-AmSC/data/rhino/Surrogate Data/2026-04-29
# RHINO data written to ADIOS-OpenPMD in particle representation.
# Output: /global/cfs/cdirs/m3239/2026_FES-AmSC/data/rhino/surrogate_bp_output/2026-04-29/14-57-21.bp5
# Converting RHINO data into openPMD/ADIOS2 format...
# Input: /global/cfs/cdirs/m3239/2026_FES-AmSC/data/rhino/Surrogate Data/2026-04-29
# RHINO data written to ADIOS-OpenPMD in particle representation.
# Output: /global/cfs/cdirs/m3239/2026_FES-AmSC/data/rhino/surrogate_bp_output/2026-04-29/14-57-54.bp5
# Converting RHINO data into openPMD/ADIOS2 format...
# Input: /global/cfs/cdirs/m3239/2026_FES-AmSC/data/rhino/Surrogate Data/2026-04-29
# RHINO data written to ADIOS-OpenPMD in particle representation.
# Output: /global/cfs/cdirs/m3239/2026_FES-AmSC/data/rhino/surrogate_bp_output/2026-04-29/14-58-24.bp5
# Converting RHINO data into openPMD/ADIOS2 format...
# Input: /global/cfs/cdirs/m3239/2026_FES-AmSC/data/rhino/Surrogate Data/2026-04-29
# RHINO data written to ADIOS-OpenPMD in particle representation.
# Output: /global/cfs/cdirs/m3239/2026_FES-AmSC/data/rhino/surrogate_bp_output/2026-04-29/14-58-55.bp5
# Converting RHINO data into openPMD/ADIOS2 format...
# Input: /global/cfs/cdirs/m3239/2026_FES-AmSC/data/rhino/Surrogate Data/2026-04-29
# RHINO data written to ADIOS-OpenPMD in particle representation.
# Output: /global/cfs/cdirs/m3239/2026_FES-AmSC/data/rhino/surrogate_bp_output/2026-04-29/14-59-26.bp5
# Converting RHINO data into openPMD/ADIOS2 format...
# Input: /global/cfs/cdirs/m3239/2026_FES-AmSC/data/rhino/Surrogate Data/2026-04-29
# RHINO data written to ADIOS-OpenPMD in particle representation.
# Output: /global/cfs/cdirs/m3239/2026_FES-AmSC/data/rhino/surrogate_bp_output/2026-04-29/14-59-57.bp5
# Converting RHINO data into openPMD/ADIOS2 format...
# Input: /global/cfs/cdirs/m3239/2026_FES-AmSC/data/rhino/Surrogate Data/2026-04-29
# RHINO data written to ADIOS-OpenPMD in particle representation.
# Output: /global/cfs/cdirs/m3239/2026_FES-AmSC/data/rhino/surrogate_bp_output/2026-04-29/15-00-31.bp5
# Converting RHINO data into openPMD/ADIOS2 format...
# Input: /global/cfs/cdirs/m3239/2026_FES-AmSC/data/rhino/Surrogate Data/2026-04-29
# RHINO data written to ADIOS-OpenPMD in particle representation.
# Output: /global/cfs/cdirs/m3239/2026_FES-AmSC/data/rhino/surrogate_bp_output/2026-04-29/15-01-02.bp5
# Converting RHINO data into openPMD/ADIOS2 format...
# Input: /global/cfs/cdirs/m3239/2026_FES-AmSC/data/rhino/Surrogate Data/2026-04-29
# RHINO data written to ADIOS-OpenPMD in particle representation.
# Output: /global/cfs/cdirs/m3239/2026_FES-AmSC/data/rhino/surrogate_bp_output/2026-04-29/15-01-34.bp5
# Converting RHINO data into openPMD/ADIOS2 format...
# Input: /global/cfs/cdirs/m3239/2026_FES-AmSC/data/rhino/Surrogate Data/2026-04-29
# RHINO data written to ADIOS-OpenPMD in particle representation.
# Output: /global/cfs/cdirs/m3239/2026_FES-AmSC/data/rhino/surrogate_bp_output/2026-04-29/15-02-06.bp5
# Converting RHINO data into openPMD/ADIOS2 format...
# Input: /global/cfs/cdirs/m3239/2026_FES-AmSC/data/rhino/Surrogate Data/2026-04-29
# RHINO data written to ADIOS-OpenPMD in particle representation.
# Output: /global/cfs/cdirs/m3239/2026_FES-AmSC/data/rhino/surrogate_bp_output/2026-04-29/15-02-39.bp5
# Converting RHINO data into openPMD/ADIOS2 format...
# Input: /global/cfs/cdirs/m3239/2026_FES-AmSC/data/rhino/Surrogate Data/2026-04-29
# RHINO data written to ADIOS-OpenPMD in particle representation.
# Output: /global/cfs/cdirs/m3239/2026_FES-AmSC/data/rhino/surrogate_bp_output/2026-04-29/15-03-10.bp5
# Converting RHINO data into openPMD/ADIOS2 format...
# Input: /global/cfs/cdirs/m3239/2026_FES-AmSC/data/rhino/Surrogate Data/2026-04-29
# RHINO data written to ADIOS-OpenPMD in particle representation.
# Output: /global/cfs/cdirs/m3239/2026_FES-AmSC/data/rhino/surrogate_bp_output/2026-04-29/15-03-43.bp5
# Converting RHINO data into openPMD/ADIOS2 format...
# Input: /global/cfs/cdirs/m3239/2026_FES-AmSC/data/rhino/Surrogate Data/2026-04-29
# RHINO data written to ADIOS-OpenPMD in particle representation.
# Output: /global/cfs/cdirs/m3239/2026_FES-AmSC/data/rhino/surrogate_bp_output/2026-04-29/15-04-16.bp5
# Converting RHINO data into openPMD/ADIOS2 format...
# Input: /global/cfs/cdirs/m3239/2026_FES-AmSC/data/rhino/Surrogate Data/2026-04-29
# RHINO data written to ADIOS-OpenPMD in particle representation.
# Output: /global/cfs/cdirs/m3239/2026_FES-AmSC/data/rhino/surrogate_bp_output/2026-04-29/15-04-47.bp5
# Converting RHINO data into openPMD/ADIOS2 format...
# Input: /global/cfs/cdirs/m3239/2026_FES-AmSC/data/rhino/Surrogate Data/2026-04-29
# RHINO data written to ADIOS-OpenPMD in particle representation.
# Output: /global/cfs/cdirs/m3239/2026_FES-AmSC/data/rhino/surrogate_bp_output/2026-04-29/15-05-19.bp5
# Converting RHINO data into openPMD/ADIOS2 format...
# Input: /global/cfs/cdirs/m3239/2026_FES-AmSC/data/rhino/Surrogate Data/2026-04-29
# RHINO data written to ADIOS-OpenPMD in particle representation.
# Output: /global/cfs/cdirs/m3239/2026_FES-AmSC/data/rhino/surrogate_bp_output/2026-04-29/15-05-50.bp5
# Converting RHINO data into openPMD/ADIOS2 format...
# Input: /global/cfs/cdirs/m3239/2026_FES-AmSC/data/rhino/Surrogate Data/2026-04-29
# RHINO data written to ADIOS-OpenPMD in particle representation.
# Output: /global/cfs/cdirs/m3239/2026_FES-AmSC/data/rhino/surrogate_bp_output/2026-04-29/15-06-22.bp5
# Converting RHINO data into openPMD/ADIOS2 format...
# Input: /global/cfs/cdirs/m3239/2026_FES-AmSC/data/rhino/Surrogate Data/2026-04-29
# RHINO data written to ADIOS-OpenPMD in particle representation.
# Output: /global/cfs/cdirs/m3239/2026_FES-AmSC/data/rhino/surrogate_bp_output/2026-04-29/15-06-56.bp5
# Converting RHINO data into openPMD/ADIOS2 format...
# Input: /global/cfs/cdirs/m3239/2026_FES-AmSC/data/rhino/Surrogate Data/2026-04-29
# RHINO data written to ADIOS-OpenPMD in particle representation.
# Output: /global/cfs/cdirs/m3239/2026_FES-AmSC/data/rhino/surrogate_bp_output/2026-04-29/15-07-28.bp5
# Converting RHINO data into openPMD/ADIOS2 format...
# Input: /global/cfs/cdirs/m3239/2026_FES-AmSC/data/rhino/Surrogate Data/2026-04-29
# RHINO data written to ADIOS-OpenPMD in particle representation.
# Output: /global/cfs/cdirs/m3239/2026_FES-AmSC/data/rhino/surrogate_bp_output/2026-04-29/15-08-01.bp5
# Converting RHINO data into openPMD/ADIOS2 format...
# Input: /global/cfs/cdirs/m3239/2026_FES-AmSC/data/rhino/Surrogate Data/2026-04-29
# RHINO data written to ADIOS-OpenPMD in particle representation.
# Output: /global/cfs/cdirs/m3239/2026_FES-AmSC/data/rhino/surrogate_bp_output/2026-04-29/15-08-32.bp5
# Converting RHINO data into openPMD/ADIOS2 format...
# Input: /global/cfs/cdirs/m3239/2026_FES-AmSC/data/rhino/Surrogate Data/2026-04-29
# RHINO data written to ADIOS-OpenPMD in particle representation.
# Output: /global/cfs/cdirs/m3239/2026_FES-AmSC/data/rhino/surrogate_bp_output/2026-04-29/15-09-06.bp5
# Converting RHINO data into openPMD/ADIOS2 format...
# Input: /global/cfs/cdirs/m3239/2026_FES-AmSC/data/rhino/Surrogate Data/2026-04-29
# RHINO data written to ADIOS-OpenPMD in particle representation.
# Output: /global/cfs/cdirs/m3239/2026_FES-AmSC/data/rhino/surrogate_bp_output/2026-04-29/15-09-37.bp5
# Converting RHINO data into openPMD/ADIOS2 format...
# Input: /global/cfs/cdirs/m3239/2026_FES-AmSC/data/rhino/Surrogate Data/2026-04-29
# RHINO data written to ADIOS-OpenPMD in particle representation.
# Output: /global/cfs/cdirs/m3239/2026_FES-AmSC/data/rhino/surrogate_bp_output/2026-04-29/15-10-10.bp5
# Converting RHINO data into openPMD/ADIOS2 format...
# Input: /global/cfs/cdirs/m3239/2026_FES-AmSC/data/rhino/Surrogate Data/2026-04-29
# RHINO data written to ADIOS-OpenPMD in particle representation.
# Output: /global/cfs/cdirs/m3239/2026_FES-AmSC/data/rhino/surrogate_bp_output/2026-04-29/15-10-42.bp5
# Converting RHINO data into openPMD/ADIOS2 format...
# Input: /global/cfs/cdirs/m3239/2026_FES-AmSC/data/rhino/Surrogate Data/2026-04-29
# RHINO data written to ADIOS-OpenPMD in particle representation.
# Output: /global/cfs/cdirs/m3239/2026_FES-AmSC/data/rhino/surrogate_bp_output/2026-04-29/15-11-15.bp5
# Converting RHINO data into openPMD/ADIOS2 format...
# Input: /global/cfs/cdirs/m3239/2026_FES-AmSC/data/rhino/Surrogate Data/2026-04-29
# RHINO data written to ADIOS-OpenPMD in particle representation.
# Output: /global/cfs/cdirs/m3239/2026_FES-AmSC/data/rhino/surrogate_bp_output/2026-04-29/15-11-46.bp5
# Converting RHINO data into openPMD/ADIOS2 format...
# Input: /global/cfs/cdirs/m3239/2026_FES-AmSC/data/rhino/Surrogate Data/2026-04-29
# RHINO data written to ADIOS-OpenPMD in particle representation.
# Output: /global/cfs/cdirs/m3239/2026_FES-AmSC/data/rhino/surrogate_bp_output/2026-04-29/15-12-18.bp5
# Converting RHINO data into openPMD/ADIOS2 format...
# Input: /global/cfs/cdirs/m3239/2026_FES-AmSC/data/rhino/Surrogate Data/2026-04-29
# RHINO data written to ADIOS-OpenPMD in particle representation.
# Output: /global/cfs/cdirs/m3239/2026_FES-AmSC/data/rhino/surrogate_bp_output/2026-04-29/15-12-49.bp5
# Converting RHINO data into openPMD/ADIOS2 format...
# Input: /global/cfs/cdirs/m3239/2026_FES-AmSC/data/rhino/Surrogate Data/2026-04-29
# RHINO data written to ADIOS-OpenPMD in particle representation.
# Output: /global/cfs/cdirs/m3239/2026_FES-AmSC/data/rhino/surrogate_bp_output/2026-04-29/15-13-24.bp5
# Converting RHINO data into openPMD/ADIOS2 format...
# Input: /global/cfs/cdirs/m3239/2026_FES-AmSC/data/rhino/Surrogate Data/2026-04-29
# RHINO data written to ADIOS-OpenPMD in particle representation.
# Output: /global/cfs/cdirs/m3239/2026_FES-AmSC/data/rhino/surrogate_bp_output/2026-04-29/15-14-00.bp5
# Converting RHINO data into openPMD/ADIOS2 format...
# Input: /global/cfs/cdirs/m3239/2026_FES-AmSC/data/rhino/Surrogate Data/2026-04-29
# RHINO data written to ADIOS-OpenPMD in particle representation.
# Output: /global/cfs/cdirs/m3239/2026_FES-AmSC/data/rhino/surrogate_bp_output/2026-04-29/15-14-33.bp5
# Converting RHINO data into openPMD/ADIOS2 format...
# Input: /global/cfs/cdirs/m3239/2026_FES-AmSC/data/rhino/Surrogate Data/2026-04-29
# RHINO data written to ADIOS-OpenPMD in particle representation.
# Output: /global/cfs/cdirs/m3239/2026_FES-AmSC/data/rhino/surrogate_bp_output/2026-04-29/15-15-04.bp5
# Converting RHINO data into openPMD/ADIOS2 format...
# Input: /global/cfs/cdirs/m3239/2026_FES-AmSC/data/rhino/Surrogate Data/2026-04-29
# RHINO data written to ADIOS-OpenPMD in particle representation.
# Output: /global/cfs/cdirs/m3239/2026_FES-AmSC/data/rhino/surrogate_bp_output/2026-04-29/15-15-35.bp5
# Converting RHINO data into openPMD/ADIOS2 format...
# Input: /global/cfs/cdirs/m3239/2026_FES-AmSC/data/rhino/Surrogate Data/2026-04-29
# RHINO data written to ADIOS-OpenPMD in particle representation.
# Output: /global/cfs/cdirs/m3239/2026_FES-AmSC/data/rhino/surrogate_bp_output/2026-04-29/15-16-07.bp5
# Converting RHINO data into openPMD/ADIOS2 format...
# Input: /global/cfs/cdirs/m3239/2026_FES-AmSC/data/rhino/Surrogate Data/2026-04-29
# RHINO data written to ADIOS-OpenPMD in particle representation.
# Output: /global/cfs/cdirs/m3239/2026_FES-AmSC/data/rhino/surrogate_bp_output/2026-04-29/15-16-39.bp5
# Converting RHINO data into openPMD/ADIOS2 format...
# Input: /global/cfs/cdirs/m3239/2026_FES-AmSC/data/rhino/Surrogate Data/2026-04-29
# RHINO data written to ADIOS-OpenPMD in particle representation.
# Output: /global/cfs/cdirs/m3239/2026_FES-AmSC/data/rhino/surrogate_bp_output/2026-04-29/15-17-11.bp5
# Converting RHINO data into openPMD/ADIOS2 format...
# Input: /global/cfs/cdirs/m3239/2026_FES-AmSC/data/rhino/Surrogate Data/2026-04-29
# RHINO data written to ADIOS-OpenPMD in particle representation.
# Output: /global/cfs/cdirs/m3239/2026_FES-AmSC/data/rhino/surrogate_bp_output/2026-04-29/15-17-44.bp5
# Converting RHINO data into openPMD/ADIOS2 format...
# Input: /global/cfs/cdirs/m3239/2026_FES-AmSC/data/rhino/Surrogate Data/2026-04-29
# RHINO data written to ADIOS-OpenPMD in particle representation.
# Output: /global/cfs/cdirs/m3239/2026_FES-AmSC/data/rhino/surrogate_bp_output/2026-04-29/15-18-17.bp5
# Converting RHINO data into openPMD/ADIOS2 format...
# Input: /global/cfs/cdirs/m3239/2026_FES-AmSC/data/rhino/Surrogate Data/2026-04-29
# RHINO data written to ADIOS-OpenPMD in particle representation.
# Output: /global/cfs/cdirs/m3239/2026_FES-AmSC/data/rhino/surrogate_bp_output/2026-04-29/15-18-49.bp5
# Converting RHINO data into openPMD/ADIOS2 format...
# Input: /global/cfs/cdirs/m3239/2026_FES-AmSC/data/rhino/Surrogate Data/2026-04-29
# RHINO data written to ADIOS-OpenPMD in particle representation.
# Output: /global/cfs/cdirs/m3239/2026_FES-AmSC/data/rhino/surrogate_bp_output/2026-04-29/15-19-22.bp5
# Converting RHINO data into openPMD/ADIOS2 format...
# Input: /global/cfs/cdirs/m3239/2026_FES-AmSC/data/rhino/Surrogate Data/2026-04-29
# RHINO data written to ADIOS-OpenPMD in particle representation.
# Output: /global/cfs/cdirs/m3239/2026_FES-AmSC/data/rhino/surrogate_bp_output/2026-04-29/15-19-54.bp5
# Converting RHINO data into openPMD/ADIOS2 format...
# Input: /global/cfs/cdirs/m3239/2026_FES-AmSC/data/rhino/Surrogate Data/2026-04-29
# RHINO data written to ADIOS-OpenPMD in particle representation.
# Output: /global/cfs/cdirs/m3239/2026_FES-AmSC/data/rhino/surrogate_bp_output/2026-04-29/15-20-26.bp5
# Converting RHINO data into openPMD/ADIOS2 format...
# Input: /global/cfs/cdirs/m3239/2026_FES-AmSC/data/rhino/Surrogate Data/2026-04-29
# RHINO data written to ADIOS-OpenPMD in particle representation.
# Output: /global/cfs/cdirs/m3239/2026_FES-AmSC/data/rhino/surrogate_bp_output/2026-04-29/15-20-59.bp5
# Converting RHINO data into openPMD/ADIOS2 format...
# Input: /global/cfs/cdirs/m3239/2026_FES-AmSC/data/rhino/Surrogate Data/2026-04-29
# RHINO data written to ADIOS-OpenPMD in particle representation.
# Output: /global/cfs/cdirs/m3239/2026_FES-AmSC/data/rhino/surrogate_bp_output/2026-04-29/15-21-32.bp5
# Converting RHINO data into openPMD/ADIOS2 format...
# Input: /global/cfs/cdirs/m3239/2026_FES-AmSC/data/rhino/Surrogate Data/2026-04-29
# RHINO data written to ADIOS-OpenPMD in particle representation.
# Output: /global/cfs/cdirs/m3239/2026_FES-AmSC/data/rhino/surrogate_bp_output/2026-04-29/15-22-03.bp5
# Converting RHINO data into openPMD/ADIOS2 format...
# Input: /global/cfs/cdirs/m3239/2026_FES-AmSC/data/rhino/Surrogate Data/2026-04-29
# RHINO data written to ADIOS-OpenPMD in particle representation.
# Output: /global/cfs/cdirs/m3239/2026_FES-AmSC/data/rhino/surrogate_bp_output/2026-04-29/15-22-36.bp5
# Converting RHINO data into openPMD/ADIOS2 format...
# Input: /global/cfs/cdirs/m3239/2026_FES-AmSC/data/rhino/Surrogate Data/2026-04-29
# RHINO data written to ADIOS-OpenPMD in particle representation.
# Output: /global/cfs/cdirs/m3239/2026_FES-AmSC/data/rhino/surrogate_bp_output/2026-04-29/15-23-09.bp5
# Converting RHINO data into openPMD/ADIOS2 format...
# Input: /global/cfs/cdirs/m3239/2026_FES-AmSC/data/rhino/Surrogate Data/2026-04-29
# RHINO data written to ADIOS-OpenPMD in particle representation.
# Output: /global/cfs/cdirs/m3239/2026_FES-AmSC/data/rhino/surrogate_bp_output/2026-04-29/15-23-41.bp5
# Converting RHINO data into openPMD/ADIOS2 format...
# Input: /global/cfs/cdirs/m3239/2026_FES-AmSC/data/rhino/Surrogate Data/2026-04-29
# RHINO data written to ADIOS-OpenPMD in particle representation.
# Output: /global/cfs/cdirs/m3239/2026_FES-AmSC/data/rhino/surrogate_bp_output/2026-04-29/15-24-14.bp5
# Converting RHINO data into openPMD/ADIOS2 format...
# Input: /global/cfs/cdirs/m3239/2026_FES-AmSC/data/rhino/Surrogate Data/2026-04-29
# RHINO data written to ADIOS-OpenPMD in particle representation.
# Output: /global/cfs/cdirs/m3239/2026_FES-AmSC/data/rhino/surrogate_bp_output/2026-04-29/15-24-45.bp5
# Converting RHINO data into openPMD/ADIOS2 format...
# Input: /global/cfs/cdirs/m3239/2026_FES-AmSC/data/rhino/Surrogate Data/2026-04-29
# RHINO data written to ADIOS-OpenPMD in particle representation.
# Output: /global/cfs/cdirs/m3239/2026_FES-AmSC/data/rhino/surrogate_bp_output/2026-04-29/15-25-18.bp5
# Converting RHINO data into openPMD/ADIOS2 format...
# Input: /global/cfs/cdirs/m3239/2026_FES-AmSC/data/rhino/Surrogate Data/2026-04-29
# RHINO data written to ADIOS-OpenPMD in particle representation.
# Output: /global/cfs/cdirs/m3239/2026_FES-AmSC/data/rhino/surrogate_bp_output/2026-04-29/15-25-51.bp5
# Converting RHINO data into openPMD/ADIOS2 format...
# Input: /global/cfs/cdirs/m3239/2026_FES-AmSC/data/rhino/Surrogate Data/2026-04-29
# RHINO data written to ADIOS-OpenPMD in particle representation.
# Output: /global/cfs/cdirs/m3239/2026_FES-AmSC/data/rhino/surrogate_bp_output/2026-04-29/15-26-23.bp5
# Converting RHINO data into openPMD/ADIOS2 format...
# Input: /global/cfs/cdirs/m3239/2026_FES-AmSC/data/rhino/Surrogate Data/2026-04-29
# RHINO data written to ADIOS-OpenPMD in particle representation.
# Output: /global/cfs/cdirs/m3239/2026_FES-AmSC/data/rhino/surrogate_bp_output/2026-04-29/15-26-55.bp5
# Converting RHINO data into openPMD/ADIOS2 format...
# Input: /global/cfs/cdirs/m3239/2026_FES-AmSC/data/rhino/Surrogate Data/2026-04-29
# RHINO data written to ADIOS-OpenPMD in particle representation.
# Output: /global/cfs/cdirs/m3239/2026_FES-AmSC/data/rhino/surrogate_bp_output/2026-04-29/15-27-27.bp5
# Converting RHINO data into openPMD/ADIOS2 format...
# Input: /global/cfs/cdirs/m3239/2026_FES-AmSC/data/rhino/Surrogate Data/2026-04-29
# RHINO data written to ADIOS-OpenPMD in particle representation.
# Output: /global/cfs/cdirs/m3239/2026_FES-AmSC/data/rhino/surrogate_bp_output/2026-04-29/15-28-00.bp5
# Converting RHINO data into openPMD/ADIOS2 format...
# Input: /global/cfs/cdirs/m3239/2026_FES-AmSC/data/rhino/Surrogate Data/2026-04-29
# RHINO data written to ADIOS-OpenPMD in particle representation.
# Output: /global/cfs/cdirs/m3239/2026_FES-AmSC/data/rhino/surrogate_bp_output/2026-04-29/15-28-32.bp5
# Converting RHINO data into openPMD/ADIOS2 format...
# Input: /global/cfs/cdirs/m3239/2026_FES-AmSC/data/rhino/Surrogate Data/2026-04-29
# RHINO data written to ADIOS-OpenPMD in particle representation.
# Output: /global/cfs/cdirs/m3239/2026_FES-AmSC/data/rhino/surrogate_bp_output/2026-04-29/15-29-04.bp5
# Converting RHINO data into openPMD/ADIOS2 format...
# Input: /global/cfs/cdirs/m3239/2026_FES-AmSC/data/rhino/Surrogate Data/2026-04-29
# RHINO data written to ADIOS-OpenPMD in particle representation.
# Output: /global/cfs/cdirs/m3239/2026_FES-AmSC/data/rhino/surrogate_bp_output/2026-04-29/15-29-37.bp5
# Converting RHINO data into openPMD/ADIOS2 format...
# Input: /global/cfs/cdirs/m3239/2026_FES-AmSC/data/rhino/Surrogate Data/2026-04-29
# RHINO data written to ADIOS-OpenPMD in particle representation.
# Output: /global/cfs/cdirs/m3239/2026_FES-AmSC/data/rhino/surrogate_bp_output/2026-04-29/15-30-10.bp5
# Converting RHINO data into openPMD/ADIOS2 format...
# Input: /global/cfs/cdirs/m3239/2026_FES-AmSC/data/rhino/Surrogate Data/2026-04-29
# RHINO data written to ADIOS-OpenPMD in particle representation.
# Output: /global/cfs/cdirs/m3239/2026_FES-AmSC/data/rhino/surrogate_bp_output/2026-04-29/15-30-43.bp5
# Converting RHINO data into openPMD/ADIOS2 format...
# Input: /global/cfs/cdirs/m3239/2026_FES-AmSC/data/rhino/Surrogate Data/2026-04-29
# RHINO data written to ADIOS-OpenPMD in particle representation.
# Output: /global/cfs/cdirs/m3239/2026_FES-AmSC/data/rhino/surrogate_bp_output/2026-04-29/15-31-15.bp5
# Converting RHINO data into openPMD/ADIOS2 format...
# Input: /global/cfs/cdirs/m3239/2026_FES-AmSC/data/rhino/Surrogate Data/2026-04-29
# RHINO data written to ADIOS-OpenPMD in particle representation.
# Output: /global/cfs/cdirs/m3239/2026_FES-AmSC/data/rhino/surrogate_bp_output/2026-04-29/15-31-48.bp5
# Converting RHINO data into openPMD/ADIOS2 format...
# Input: /global/cfs/cdirs/m3239/2026_FES-AmSC/data/rhino/Surrogate Data/2026-04-29
# RHINO data written to ADIOS-OpenPMD in particle representation.
# Output: /global/cfs/cdirs/m3239/2026_FES-AmSC/data/rhino/surrogate_bp_output/2026-04-29/15-32-21.bp5
# Converting RHINO data into openPMD/ADIOS2 format...
# Input: /global/cfs/cdirs/m3239/2026_FES-AmSC/data/rhino/Surrogate Data/2026-04-29
# RHINO data written to ADIOS-OpenPMD in particle representation.
# Output: /global/cfs/cdirs/m3239/2026_FES-AmSC/data/rhino/surrogate_bp_output/2026-04-29/15-32-52.bp5
# Converting RHINO data into openPMD/ADIOS2 format...
# Input: /global/cfs/cdirs/m3239/2026_FES-AmSC/data/rhino/Surrogate Data/2026-04-29
# RHINO data written to ADIOS-OpenPMD in particle representation.
# Output: /global/cfs/cdirs/m3239/2026_FES-AmSC/data/rhino/surrogate_bp_output/2026-04-29/15-33-26.bp5
# Converting RHINO data into openPMD/ADIOS2 format...
# Input: /global/cfs/cdirs/m3239/2026_FES-AmSC/data/rhino/Surrogate Data/2026-04-29
# RHINO data written to ADIOS-OpenPMD in particle representation.
# Output: /global/cfs/cdirs/m3239/2026_FES-AmSC/data/rhino/surrogate_bp_output/2026-04-29/15-33-59.bp5
# Converting RHINO data into openPMD/ADIOS2 format...
# Input: /global/cfs/cdirs/m3239/2026_FES-AmSC/data/rhino/Surrogate Data/2026-04-29
# RHINO data written to ADIOS-OpenPMD in particle representation.
# Output: /global/cfs/cdirs/m3239/2026_FES-AmSC/data/rhino/surrogate_bp_output/2026-04-29/15-34-32.bp5
# Converting RHINO data into openPMD/ADIOS2 format...
# Input: /global/cfs/cdirs/m3239/2026_FES-AmSC/data/rhino/Surrogate Data/2026-04-29
# RHINO data written to ADIOS-OpenPMD in particle representation.
# Output: /global/cfs/cdirs/m3239/2026_FES-AmSC/data/rhino/surrogate_bp_output/2026-04-29/15-35-04.bp5
# Converting RHINO data into openPMD/ADIOS2 format...
# Input: /global/cfs/cdirs/m3239/2026_FES-AmSC/data/rhino/Surrogate Data/2026-04-29
# RHINO data written to ADIOS-OpenPMD in particle representation.
# Output: /global/cfs/cdirs/m3239/2026_FES-AmSC/data/rhino/surrogate_bp_output/2026-04-29/15-35-37.bp5
# Converting RHINO data into openPMD/ADIOS2 format...
# Input: /global/cfs/cdirs/m3239/2026_FES-AmSC/data/rhino/Surrogate Data/2026-04-29
# RHINO data written to ADIOS-OpenPMD in particle representation.
# Output: /global/cfs/cdirs/m3239/2026_FES-AmSC/data/rhino/surrogate_bp_output/2026-04-29/15-36-08.bp5
# Converting RHINO data into openPMD/ADIOS2 format...
# Input: /global/cfs/cdirs/m3239/2026_FES-AmSC/data/rhino/Surrogate Data/2026-04-29
# RHINO data written to ADIOS-OpenPMD in particle representation.
# Output: /global/cfs/cdirs/m3239/2026_FES-AmSC/data/rhino/surrogate_bp_output/2026-04-29/15-36-40.bp5
# Converting RHINO data into openPMD/ADIOS2 format...
# Input: /global/cfs/cdirs/m3239/2026_FES-AmSC/data/rhino/Surrogate Data/2026-04-29
# RHINO data written to ADIOS-OpenPMD in particle representation.
# Output: /global/cfs/cdirs/m3239/2026_FES-AmSC/data/rhino/surrogate_bp_output/2026-04-29/15-37-12.bp5
# Converting RHINO data into openPMD/ADIOS2 format...
# Input: /global/cfs/cdirs/m3239/2026_FES-AmSC/data/rhino/Surrogate Data/2026-04-29
# RHINO data written to ADIOS-OpenPMD in particle representation.
# Output: /global/cfs/cdirs/m3239/2026_FES-AmSC/data/rhino/surrogate_bp_output/2026-04-29/15-37-43.bp5
# Converting RHINO data into openPMD/ADIOS2 format...
# Input: /global/cfs/cdirs/m3239/2026_FES-AmSC/data/rhino/Surrogate Data/2026-04-29
# RHINO data written to ADIOS-OpenPMD in particle representation.
# Output: /global/cfs/cdirs/m3239/2026_FES-AmSC/data/rhino/surrogate_bp_output/2026-04-29/15-38-16.bp5
# Converting RHINO data into openPMD/ADIOS2 format...
# Input: /global/cfs/cdirs/m3239/2026_FES-AmSC/data/rhino/Surrogate Data/2026-04-29
# RHINO data written to ADIOS-OpenPMD in particle representation.
# Output: /global/cfs/cdirs/m3239/2026_FES-AmSC/data/rhino/surrogate_bp_output/2026-04-29/15-38-49.bp5
# Converting RHINO data into openPMD/ADIOS2 format...
# Input: /global/cfs/cdirs/m3239/2026_FES-AmSC/data/rhino/Surrogate Data/2026-04-29
# RHINO data written to ADIOS-OpenPMD in particle representation.
# Output: /global/cfs/cdirs/m3239/2026_FES-AmSC/data/rhino/surrogate_bp_output/2026-04-29/15-39-22.bp5
# Converting RHINO data into openPMD/ADIOS2 format...
# Input: /global/cfs/cdirs/m3239/2026_FES-AmSC/data/rhino/Surrogate Data/2026-04-29
# RHINO data written to ADIOS-OpenPMD in particle representation.
# Output: /global/cfs/cdirs/m3239/2026_FES-AmSC/data/rhino/surrogate_bp_output/2026-04-29/15-39-55.bp5
# Converting RHINO data into openPMD/ADIOS2 format...
# Input: /global/cfs/cdirs/m3239/2026_FES-AmSC/data/rhino/Surrogate Data/2026-04-29
# RHINO data written to ADIOS-OpenPMD in particle representation.
# Output: /global/cfs/cdirs/m3239/2026_FES-AmSC/data/rhino/surrogate_bp_output/2026-04-29/15-40-29.bp5
# Converting RHINO data into openPMD/ADIOS2 format...
# Input: /global/cfs/cdirs/m3239/2026_FES-AmSC/data/rhino/Surrogate Data/2026-04-29
# RHINO data written to ADIOS-OpenPMD in particle representation.
# Output: /global/cfs/cdirs/m3239/2026_FES-AmSC/data/rhino/surrogate_bp_output/2026-04-29/15-41-01.bp5
# Converting RHINO data into openPMD/ADIOS2 format...
# Input: /global/cfs/cdirs/m3239/2026_FES-AmSC/data/rhino/Surrogate Data/2026-04-29
# RHINO data written to ADIOS-OpenPMD in particle representation.
# Output: /global/cfs/cdirs/m3239/2026_FES-AmSC/data/rhino/surrogate_bp_output/2026-04-29/15-41-33.bp5
# Converting RHINO data into openPMD/ADIOS2 format...
# Input: /global/cfs/cdirs/m3239/2026_FES-AmSC/data/rhino/Surrogate Data/2026-04-29
# RHINO data written to ADIOS-OpenPMD in particle representation.
# Output: /global/cfs/cdirs/m3239/2026_FES-AmSC/data/rhino/surrogate_bp_output/2026-04-29/15-42-04.bp5
# Converting RHINO data into openPMD/ADIOS2 format...
# Input: /global/cfs/cdirs/m3239/2026_FES-AmSC/data/rhino/Surrogate Data/2026-04-29
# RHINO data written to ADIOS-OpenPMD in particle representation.
# Output: /global/cfs/cdirs/m3239/2026_FES-AmSC/data/rhino/surrogate_bp_output/2026-04-29/15-42-37.bp5
# Converting RHINO data into openPMD/ADIOS2 format...
# Input: /global/cfs/cdirs/m3239/2026_FES-AmSC/data/rhino/Surrogate Data/2026-04-29
# RHINO data written to ADIOS-OpenPMD in particle representation.
# Output: /global/cfs/cdirs/m3239/2026_FES-AmSC/data/rhino/surrogate_bp_output/2026-04-29/15-43-10.bp5
# Converting RHINO data into openPMD/ADIOS2 format...
# Input: /global/cfs/cdirs/m3239/2026_FES-AmSC/data/rhino/Surrogate Data/2026-04-29
# RHINO data written to ADIOS-OpenPMD in particle representation.
# Output: /global/cfs/cdirs/m3239/2026_FES-AmSC/data/rhino/surrogate_bp_output/2026-04-29/15-43-42.bp5
# Converting RHINO data into openPMD/ADIOS2 format...
# Input: /global/cfs/cdirs/m3239/2026_FES-AmSC/data/rhino/Surrogate Data/2026-04-29
# RHINO data written to ADIOS-OpenPMD in particle representation.
# Output: /global/cfs/cdirs/m3239/2026_FES-AmSC/data/rhino/surrogate_bp_output/2026-04-29/15-44-16.bp5
# Converting RHINO data into openPMD/ADIOS2 format...
# Input: /global/cfs/cdirs/m3239/2026_FES-AmSC/data/rhino/Surrogate Data/2026-04-29
# RHINO data written to ADIOS-OpenPMD in particle representation.
# Output: /global/cfs/cdirs/m3239/2026_FES-AmSC/data/rhino/surrogate_bp_output/2026-04-29/15-44-47.bp5
# Converting RHINO data into openPMD/ADIOS2 format...
# Input: /global/cfs/cdirs/m3239/2026_FES-AmSC/data/rhino/Surrogate Data/2026-04-29
# RHINO data written to ADIOS-OpenPMD in particle representation.
# Output: /global/cfs/cdirs/m3239/2026_FES-AmSC/data/rhino/surrogate_bp_output/2026-04-29/15-45-19.bp5
# Converting RHINO data into openPMD/ADIOS2 format...
# Input: /global/cfs/cdirs/m3239/2026_FES-AmSC/data/rhino/Surrogate Data/2026-04-29
# RHINO data written to ADIOS-OpenPMD in particle representation.
# Output: /global/cfs/cdirs/m3239/2026_FES-AmSC/data/rhino/surrogate_bp_output/2026-04-29/15-45-51.bp5
# Converting RHINO data into openPMD/ADIOS2 format...
# Input: /global/cfs/cdirs/m3239/2026_FES-AmSC/data/rhino/Surrogate Data/2026-04-29
# RHINO data written to ADIOS-OpenPMD in particle representation.
# Output: /global/cfs/cdirs/m3239/2026_FES-AmSC/data/rhino/surrogate_bp_output/2026-04-29/15-46-24.bp5
# Converting RHINO data into openPMD/ADIOS2 format...
# Input: /global/cfs/cdirs/m3239/2026_FES-AmSC/data/rhino/Surrogate Data/2026-04-29
# ...
# Converting RHINO data into openPMD/ADIOS2 format...
# Input: /global/cfs/cdirs/m3239/2026_FES-AmSC/data/rhino/Surrogate Data/2026-05-01
# RHINO data written to ADIOS-OpenPMD in particle representation.
# Output: /global/cfs/cdirs/m3239/2026_FES-AmSC/data/rhino/surrogate_bp_output/2026-05-01/08-17-59.bp5
# Converting RHINO data into openPMD/ADIOS2 format...
# Input: /global/cfs/cdirs/m3239/2026_FES-AmSC/data/rhino/Surrogate Data/2026-05-01
# RHINO data written to ADIOS-OpenPMD in particle representation.
# Output: /global/cfs/cdirs/m3239/2026_FES-AmSC/data/rhino/surrogate_bp_output/2026-05-01/08-18-50.bp5
# Converting RHINO data into openPMD/ADIOS2 format...
# Input: /global/cfs/cdirs/m3239/2026_FES-AmSC/data/rhino/Surrogate Data/2026-05-01
# RHINO data written to ADIOS-OpenPMD in particle representation.
# Output: /global/cfs/cdirs/m3239/2026_FES-AmSC/data/rhino/surrogate_bp_output/2026-05-01/08-19-42.bp5
# Converting RHINO data into openPMD/ADIOS2 format...
# Input: /global/cfs/cdirs/m3239/2026_FES-AmSC/data/rhino/Surrogate Data/2026-05-01
# RHINO data written to ADIOS-OpenPMD in particle representation.
# Output: /global/cfs/cdirs/m3239/2026_FES-AmSC/data/rhino/surrogate_bp_output/2026-05-01/08-20-33.bp5
# Converting RHINO data into openPMD/ADIOS2 format...
# Input: /global/cfs/cdirs/m3239/2026_FES-AmSC/data/rhino/Surrogate Data/2026-05-01
# RHINO data written to ADIOS-OpenPMD in particle representation.
# Output: /global/cfs/cdirs/m3239/2026_FES-AmSC/data/rhino/surrogate_bp_output/2026-05-01/08-21-25.bp5
# Converting RHINO data into openPMD/ADIOS2 format...
# Input: /global/cfs/cdirs/m3239/2026_FES-AmSC/data/rhino/Surrogate Data/2026-05-01
# RHINO data written to ADIOS-OpenPMD in particle representation.
# Output: /global/cfs/cdirs/m3239/2026_FES-AmSC/data/rhino/surrogate_bp_output/2026-05-01/08-22-17.bp5
# Converting RHINO data into openPMD/ADIOS2 format...
# Input: /global/cfs/cdirs/m3239/2026_FES-AmSC/data/rhino/Surrogate Data/2026-05-01
# RHINO data written to ADIOS-OpenPMD in particle representation.
# Output: /global/cfs/cdirs/m3239/2026_FES-AmSC/data/rhino/surrogate_bp_output/2026-05-01/08-23-07.bp5
# Converting RHINO data into openPMD/ADIOS2 format...
# Input: /global/cfs/cdirs/m3239/2026_FES-AmSC/data/rhino/Surrogate Data/2026-05-01
# RHINO data written to ADIOS-OpenPMD in particle representation.
# Output: /global/cfs/cdirs/m3239/2026_FES-AmSC/data/rhino/surrogate_bp_output/2026-05-01/08-23-58.bp5
# Converting RHINO data into openPMD/ADIOS2 format...
# Input: /global/cfs/cdirs/m3239/2026_FES-AmSC/data/rhino/Surrogate Data/2026-05-01
# RHINO data written to ADIOS-OpenPMD in particle representation.
# Output: /global/cfs/cdirs/m3239/2026_FES-AmSC/data/rhino/surrogate_bp_output/2026-05-01/08-24-50.bp5
# Converting RHINO data into openPMD/ADIOS2 format...
# Input: /global/cfs/cdirs/m3239/2026_FES-AmSC/data/rhino/Surrogate Data/2026-05-01
# RHINO data written to ADIOS-OpenPMD in particle representation.
# Output: /global/cfs/cdirs/m3239/2026_FES-AmSC/data/rhino/surrogate_bp_output/2026-05-01/08-25-41.bp5
# Converting RHINO data into openPMD/ADIOS2 format...
# Input: /global/cfs/cdirs/m3239/2026_FES-AmSC/data/rhino/Surrogate Data/2026-05-01
# RHINO data written to ADIOS-OpenPMD in particle representation.
# Output: /global/cfs/cdirs/m3239/2026_FES-AmSC/data/rhino/surrogate_bp_output/2026-05-01/08-26-33.bp5
# Converting RHINO data into openPMD/ADIOS2 format...
# Input: /global/cfs/cdirs/m3239/2026_FES-AmSC/data/rhino/Surrogate Data/2026-05-01
# RHINO data written to ADIOS-OpenPMD in particle representation.
# Output: /global/cfs/cdirs/m3239/2026_FES-AmSC/data/rhino/surrogate_bp_output/2026-05-01/08-27-24.bp5
# Converting RHINO data into openPMD/ADIOS2 format...
# Input: /global/cfs/cdirs/m3239/2026_FES-AmSC/data/rhino/Surrogate Data/2026-05-01
# RHINO data written to ADIOS-OpenPMD in particle representation.
# Output: /global/cfs/cdirs/m3239/2026_FES-AmSC/data/rhino/surrogate_bp_output/2026-05-01/08-28-16.bp5
# Converting RHINO data into openPMD/ADIOS2 format...
# Input: /global/cfs/cdirs/m3239/2026_FES-AmSC/data/rhino/Surrogate Data/2026-05-01
# RHINO data written to ADIOS-OpenPMD in particle representation.
# Output: /global/cfs/cdirs/m3239/2026_FES-AmSC/data/rhino/surrogate_bp_output/2026-05-01/08-29-08.bp5
# Converting RHINO data into openPMD/ADIOS2 format...
# Input: /global/cfs/cdirs/m3239/2026_FES-AmSC/data/rhino/Surrogate Data/2026-05-01
# RHINO data written to ADIOS-OpenPMD in particle representation.
# Output: /global/cfs/cdirs/m3239/2026_FES-AmSC/data/rhino/surrogate_bp_output/2026-05-01/08-29-59.bp5
# Converting RHINO data into openPMD/ADIOS2 format...
# Input: /global/cfs/cdirs/m3239/2026_FES-AmSC/data/rhino/Surrogate Data/2026-05-01
# RHINO data written to ADIOS-OpenPMD in particle representation.
# Output: /global/cfs/cdirs/m3239/2026_FES-AmSC/data/rhino/surrogate_bp_output/2026-05-01/08-30-51.bp5
# Converting RHINO data into openPMD/ADIOS2 format...
# Input: /global/cfs/cdirs/m3239/2026_FES-AmSC/data/rhino/Surrogate Data/2026-05-01
# RHINO data written to ADIOS-OpenPMD in particle representation.
# Output: /global/cfs/cdirs/m3239/2026_FES-AmSC/data/rhino/surrogate_bp_output/2026-05-01/08-31-42.bp5
# Converting RHINO data into openPMD/ADIOS2 format...
# Input: /global/cfs/cdirs/m3239/2026_FES-AmSC/data/rhino/Surrogate Data/2026-05-01
# RHINO data written to ADIOS-OpenPMD in particle representation.
# Output: /global/cfs/cdirs/m3239/2026_FES-AmSC/data/rhino/surrogate_bp_output/2026-05-01/08-32-34.bp5
# Converting RHINO data into openPMD/ADIOS2 format...
# Input: /global/cfs/cdirs/m3239/2026_FES-AmSC/data/rhino/Surrogate Data/2026-05-01
# RHINO data written to ADIOS-OpenPMD in particle representation.
# Output: /global/cfs/cdirs/m3239/2026_FES-AmSC/data/rhino/surrogate_bp_output/2026-05-01/08-33-26.bp5
# Converting RHINO data into openPMD/ADIOS2 format...
# Input: /global/cfs/cdirs/m3239/2026_FES-AmSC/data/rhino/Surrogate Data/2026-05-01
# RHINO data written to ADIOS-OpenPMD in particle representation.
# Output: /global/cfs/cdirs/m3239/2026_FES-AmSC/data/rhino/surrogate_bp_output/2026-05-01/08-34-21.bp5
# Converting RHINO data into openPMD/ADIOS2 format...
# Input: /global/cfs/cdirs/m3239/2026_FES-AmSC/data/rhino/Surrogate Data/2026-05-01
# RHINO data written to ADIOS-OpenPMD in particle representation.
# Output: /global/cfs/cdirs/m3239/2026_FES-AmSC/data/rhino/surrogate_bp_output/2026-05-01/08-35-21.bp5
# Converting RHINO data into openPMD/ADIOS2 format...
# Input: /global/cfs/cdirs/m3239/2026_FES-AmSC/data/rhino/Surrogate Data/2026-05-01
# RHINO data written to ADIOS-OpenPMD in particle representation.
# Output: /global/cfs/cdirs/m3239/2026_FES-AmSC/data/rhino/surrogate_bp_output/2026-05-01/08-36-19.bp5
# Converting RHINO data into openPMD/ADIOS2 format...
# Input: /global/cfs/cdirs/m3239/2026_FES-AmSC/data/rhino/Surrogate Data/2026-05-01
# RHINO data written to ADIOS-OpenPMD in particle representation.
# Output: /global/cfs/cdirs/m3239/2026_FES-AmSC/data/rhino/surrogate_bp_output/2026-05-01/08-37-16.bp5
# Converting RHINO data into openPMD/ADIOS2 format...
# Input: /global/cfs/cdirs/m3239/2026_FES-AmSC/data/rhino/Surrogate Data/2026-05-01
# RHINO data written to ADIOS-OpenPMD in particle representation.
# Output: /global/cfs/cdirs/m3239/2026_FES-AmSC/data/rhino/surrogate_bp_output/2026-05-01/08-38-14.bp5
# Converting RHINO data into openPMD/ADIOS2 format...
# Input: /global/cfs/cdirs/m3239/2026_FES-AmSC/data/rhino/Surrogate Data/2026-05-01
# RHINO data written to ADIOS-OpenPMD in particle representation.
# Output: /global/cfs/cdirs/m3239/2026_FES-AmSC/data/rhino/surrogate_bp_output/2026-05-01/08-39-28.bp5
# Converting RHINO data into openPMD/ADIOS2 format...
# Input: /global/cfs/cdirs/m3239/2026_FES-AmSC/data/rhino/Surrogate Data/2026-05-01
# RHINO data written to ADIOS-OpenPMD in particle representation.
# Output: /global/cfs/cdirs/m3239/2026_FES-AmSC/data/rhino/surrogate_bp_output/2026-05-01/08-40-35.bp5
# Converting RHINO data into openPMD/ADIOS2 format...
# Input: /global/cfs/cdirs/m3239/2026_FES-AmSC/data/rhino/Surrogate Data/2026-05-01
# RHINO data written to ADIOS-OpenPMD in particle representation.
# Output: /global/cfs/cdirs/m3239/2026_FES-AmSC/data/rhino/surrogate_bp_output/2026-05-01/08-41-29.bp5
# Converting RHINO data into openPMD/ADIOS2 format...
# Input: /global/cfs/cdirs/m3239/2026_FES-AmSC/data/rhino/Surrogate Data/2026-05-01
# RHINO data written to ADIOS-OpenPMD in particle representation.
# Output: /global/cfs/cdirs/m3239/2026_FES-AmSC/data/rhino/surrogate_bp_output/2026-05-01/08-42-19.bp5
# Converting RHINO data into openPMD/ADIOS2 format...
# Input: /global/cfs/cdirs/m3239/2026_FES-AmSC/data/rhino/Surrogate Data/2026-05-01
# RHINO data written to ADIOS-OpenPMD in particle representation.
# Output: /global/cfs/cdirs/m3239/2026_FES-AmSC/data/rhino/surrogate_bp_output/2026-05-01/08-43-09.bp5
# Converting RHINO data into openPMD/ADIOS2 format...
# Input: /global/cfs/cdirs/m3239/2026_FES-AmSC/data/rhino/Surrogate Data/2026-05-01
# RHINO data written to ADIOS-OpenPMD in particle representation.
# Output: /global/cfs/cdirs/m3239/2026_FES-AmSC/data/rhino/surrogate_bp_output/2026-05-01/08-44-00.bp5
# Converting RHINO data into openPMD/ADIOS2 format...
# Input: /global/cfs/cdirs/m3239/2026_FES-AmSC/data/rhino/Surrogate Data/2026-05-01
# RHINO data written to ADIOS-OpenPMD in particle representation.
# Output: /global/cfs/cdirs/m3239/2026_FES-AmSC/data/rhino/surrogate_bp_output/2026-05-01/08-44-50.bp5
# Converting RHINO data into openPMD/ADIOS2 format...
# Input: /global/cfs/cdirs/m3239/2026_FES-AmSC/data/rhino/Surrogate Data/2026-05-01
# RHINO data written to ADIOS-OpenPMD in particle representation.
# Output: /global/cfs/cdirs/m3239/2026_FES-AmSC/data/rhino/surrogate_bp_output/2026-05-01/08-45-43.bp5
# Converting RHINO data into openPMD/ADIOS2 format...
# Input: /global/cfs/cdirs/m3239/2026_FES-AmSC/data/rhino/Surrogate Data/2026-05-01
# RHINO data written to ADIOS-OpenPMD in particle representation.
# Output: /global/cfs/cdirs/m3239/2026_FES-AmSC/data/rhino/surrogate_bp_output/2026-05-01/08-46-34.bp5
# Converting RHINO data into openPMD/ADIOS2 format...
# Input: /global/cfs/cdirs/m3239/2026_FES-AmSC/data/rhino/Surrogate Data/2026-05-01
# RHINO data written to ADIOS-OpenPMD in particle representation.
# Output: /global/cfs/cdirs/m3239/2026_FES-AmSC/data/rhino/surrogate_bp_output/2026-05-01/08-47-25.bp5
# Converting RHINO data into openPMD/ADIOS2 format...
# Input: /global/cfs/cdirs/m3239/2026_FES-AmSC/data/rhino/Surrogate Data/2026-05-01
# RHINO data written to ADIOS-OpenPMD in particle representation.
# Output: /global/cfs/cdirs/m3239/2026_FES-AmSC/data/rhino/surrogate_bp_output/2026-05-01/08-48-16.bp5
# Converting RHINO data into openPMD/ADIOS2 format...
# Input: /global/cfs/cdirs/m3239/2026_FES-AmSC/data/rhino/Surrogate Data/2026-05-01
# RHINO data written to ADIOS-OpenPMD in particle representation.
# Output: /global/cfs/cdirs/m3239/2026_FES-AmSC/data/rhino/surrogate_bp_output/2026-05-01/08-49-08.bp5
# Converting RHINO data into openPMD/ADIOS2 format...
# Input: /global/cfs/cdirs/m3239/2026_FES-AmSC/data/rhino/Surrogate Data/2026-05-01
# RHINO data written to ADIOS-OpenPMD in particle representation.
# Output: /global/cfs/cdirs/m3239/2026_FES-AmSC/data/rhino/surrogate_bp_output/2026-05-01/08-49-59.bp5
# Converting RHINO data into openPMD/ADIOS2 format...
# Input: /global/cfs/cdirs/m3239/2026_FES-AmSC/data/rhino/Surrogate Data/2026-05-01
# RHINO data written to ADIOS-OpenPMD in particle representation.
# Output: /global/cfs/cdirs/m3239/2026_FES-AmSC/data/rhino/surrogate_bp_output/2026-05-01/08-50-50.bp5
# Converting RHINO data into openPMD/ADIOS2 format...
# Input: /global/cfs/cdirs/m3239/2026_FES-AmSC/data/rhino/Surrogate Data/2026-05-01
# RHINO data written to ADIOS-OpenPMD in particle representation.
# Output: /global/cfs/cdirs/m3239/2026_FES-AmSC/data/rhino/surrogate_bp_output/2026-05-01/08-51-41.bp5
# Converting RHINO data into openPMD/ADIOS2 format...
# Input: /global/cfs/cdirs/m3239/2026_FES-AmSC/data/rhino/Surrogate Data/2026-05-01
# RHINO data written to ADIOS-OpenPMD in particle representation.
# Output: /global/cfs/cdirs/m3239/2026_FES-AmSC/data/rhino/surrogate_bp_output/2026-05-01/08-52-33.bp5
# Converting RHINO data into openPMD/ADIOS2 format...
# Input: /global/cfs/cdirs/m3239/2026_FES-AmSC/data/rhino/Surrogate Data/2026-05-01
# RHINO data written to ADIOS-OpenPMD in particle representation.
# Output: /global/cfs/cdirs/m3239/2026_FES-AmSC/data/rhino/surrogate_bp_output/2026-05-01/08-53-24.bp5
# Converting RHINO data into openPMD/ADIOS2 format...
# Input: /global/cfs/cdirs/m3239/2026_FES-AmSC/data/rhino/Surrogate Data/2026-05-01
# RHINO data written to ADIOS-OpenPMD in particle representation.
# Output: /global/cfs/cdirs/m3239/2026_FES-AmSC/data/rhino/surrogate_bp_output/2026-05-01/08-54-16.bp5
# Converting RHINO data into openPMD/ADIOS2 format...
# Input: /global/cfs/cdirs/m3239/2026_FES-AmSC/data/rhino/Surrogate Data/2026-05-01
# RHINO data written to ADIOS-OpenPMD in particle representation.
# Output: /global/cfs/cdirs/m3239/2026_FES-AmSC/data/rhino/surrogate_bp_output/2026-05-01/08-55-07.bp5
# Converting RHINO data into openPMD/ADIOS2 format...
# Input: /global/cfs/cdirs/m3239/2026_FES-AmSC/data/rhino/Surrogate Data/2026-05-01
# RHINO data written to ADIOS-OpenPMD in particle representation.
# Output: /global/cfs/cdirs/m3239/2026_FES-AmSC/data/rhino/surrogate_bp_output/2026-05-01/08-55-58.bp5
# Converting RHINO data into openPMD/ADIOS2 format...
# Input: /global/cfs/cdirs/m3239/2026_FES-AmSC/data/rhino/Surrogate Data/2026-05-01
# RHINO data written to ADIOS-OpenPMD in particle representation.
# Output: /global/cfs/cdirs/m3239/2026_FES-AmSC/data/rhino/surrogate_bp_output/2026-05-01/08-56-49.bp5
# Converting RHINO data into openPMD/ADIOS2 format...
# Input: /global/cfs/cdirs/m3239/2026_FES-AmSC/data/rhino/Surrogate Data/2026-05-01
# RHINO data written to ADIOS-OpenPMD in particle representation.
# Output: /global/cfs/cdirs/m3239/2026_FES-AmSC/data/rhino/surrogate_bp_output/2026-05-01/08-57-40.bp5
# Converting RHINO data into openPMD/ADIOS2 format...
# Input: /global/cfs/cdirs/m3239/2026_FES-AmSC/data/rhino/Surrogate Data/2026-05-01
# RHINO data written to ADIOS-OpenPMD in particle representation.
# Output: /global/cfs/cdirs/m3239/2026_FES-AmSC/data/rhino/surrogate_bp_output/2026-05-01/08-58-36.bp5
# Converting RHINO data into openPMD/ADIOS2 format...
# Input: /global/cfs/cdirs/m3239/2026_FES-AmSC/data/rhino/Surrogate Data/2026-05-01
# RHINO data written to ADIOS-OpenPMD in particle representation.
# Output: /global/cfs/cdirs/m3239/2026_FES-AmSC/data/rhino/surrogate_bp_output/2026-05-01/08-59-33.bp5
# Converting RHINO data into openPMD/ADIOS2 format...
# Input: /global/cfs/cdirs/m3239/2026_FES-AmSC/data/rhino/Surrogate Data/2026-05-01
# RHINO data written to ADIOS-OpenPMD in particle representation.
# Output: /global/cfs/cdirs/m3239/2026_FES-AmSC/data/rhino/surrogate_bp_output/2026-05-01/09-00-30.bp5
# Converting RHINO data into openPMD/ADIOS2 format...
# Input: /global/cfs/cdirs/m3239/2026_FES-AmSC/data/rhino/Surrogate Data/2026-05-01
# RHINO data written to ADIOS-OpenPMD in particle representation.
# Output: /global/cfs/cdirs/m3239/2026_FES-AmSC/data/rhino/surrogate_bp_output/2026-05-01/09-01-27.bp5
# Converting RHINO data into openPMD/ADIOS2 format...
# Input: /global/cfs/cdirs/m3239/2026_FES-AmSC/data/rhino/Surrogate Data/2026-05-01
# RHINO data written to ADIOS-OpenPMD in particle representation.
# Output: /global/cfs/cdirs/m3239/2026_FES-AmSC/data/rhino/surrogate_bp_output/2026-05-01/09-02-26.bp5
# Converting RHINO data into openPMD/ADIOS2 format...
# Input: /global/cfs/cdirs/m3239/2026_FES-AmSC/data/rhino/Surrogate Data/2026-05-01
# RHINO data written to ADIOS-OpenPMD in particle representation.
# Output: /global/cfs/cdirs/m3239/2026_FES-AmSC/data/rhino/surrogate_bp_output/2026-05-01/09-03-24.bp5
# Converting RHINO data into openPMD/ADIOS2 format...
# Input: /global/cfs/cdirs/m3239/2026_FES-AmSC/data/rhino/Surrogate Data/2026-05-01
# RHINO data written to ADIOS-OpenPMD in particle representation.
# Output: /global/cfs/cdirs/m3239/2026_FES-AmSC/data/rhino/surrogate_bp_output/2026-05-01/09-04-18.bp5
# Converting RHINO data into openPMD/ADIOS2 format...
# Input: /global/cfs/cdirs/m3239/2026_FES-AmSC/data/rhino/Surrogate Data/2026-05-01
